# %%
import numpy as np
import pickle

# %%
df = np.load("base2.npy",allow_pickle=True)

# %%
df=list(df)
df
# Out:
# [array([array([[[0.8392157 , 0.6117647 , 0.7137255 ],
#          [0.87058824, 0.6745098 , 0.7411765 ],
#          [0.7254902 , 0.53333336, 0.6666667 ],
#          ...,
#          [0.9254902 , 0.8       , 0.84313726],
#          [0.9137255 , 0.8       , 0.8352941 ],
#          [0.88235295, 0.70980394, 0.7764706 ]],
#
#         [[0.8627451 , 0.5019608 , 0.59607846],
#          [0.8509804 , 0.6431373 , 0.7411765 ],
#          [0.6862745 , 0.48235294, 0.60784316],
#          ...,
#          [0.9372549 , 0.91764706, 0.93333334],
#          [0.9529412 , 0.92156863, 0.9411765 ],
#          [0.95686275, 0.92156863, 0.93333334]],
#
#         [[0.8666667 , 0.49019608, 0.62352943],
#          [0.85882354, 0.627451  , 0.7176471 ],
#          [0.7019608 , 0.5019608 , 0.65882355],
#          ...,
#          [0.95686275, 0.91764706, 0.91764706],
#          [0.9411765 , 0.93333334, 0.9372549 ],
#          [0.95686275, 0.9372549 , 0.9372549 ]],
#
#         ...,
#
# ...

# %%
df=np.array(df)
np.shape(df)
# Out:
# (416, 2)

# %%
import pandas as pd
df2=pd.DataFrame(df)

# %%
df2.head(5)
# Out:
#                                                    0  1
# 0  [[[0.8392157, 0.6117647, 0.7137255], [0.870588...  0
# 1  [[[0.8509804, 0.54901963, 0.65882355], [0.8588...  0
# 2  [[[0.8745098, 0.54509807, 0.65882355], [0.8392...  0
# 3  [[[0.8235294, 0.47843137, 0.6156863], [0.80392...  0
# 4  [[[0.84313726, 0.5647059, 0.68235296], [0.8235...  0
